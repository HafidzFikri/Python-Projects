# %%
for i in range(10):
  j = 10 - i
  print(" "*j + "*"*20)
# Out:
#           ********************
#          ********************
#         ********************
#        ********************
#       ********************
#      ********************
#     ********************
#    ********************
#   ********************
#  ********************

# %%
for i in range(5):
  j = 5 + i
  k = 5 - i
  print(" "*k + "*"*j + "*"*j)
  if i == 4:
    for j in range(i):
      j = 4 + i
      k = 6 - i
      print(" "*k + "*"*j + "*"*j)
      i -= 1
# Out:
#      **********
#     ************
#    **************
#   ****************
#  ******************
#   ****************
#    **************
#     ************
#      **********

# %%
for i in range(1,10):
  k = 10 - i
  print("*"*i + " " * k + " " * k + "*"*i)
  if i == 9:
    i = i - 1
    for j in range(i):
      k = 10 - i
      print("*"*i + " " * k + " " * k + "*"*i)
      i -= 1
# Out:
# *                  *
# **                **
# ***              ***
# ****            ****
# *****          *****
# ******        ******
# *******      *******
# ********    ********
# *********  *********
# ********    ********
# *******      *******
# ******        ******
# *****          *****
# ****            ****
# ***              ***
# **                **
# *                  *

# %%
for i in range(1,10):
  k = 10 - i
  print(" "*i + "*" * k + "*" * k + " "*i)
  if i == 9:
    i = i
    for j in range(i):
      k = 10 - i
      print(" "*i + "*" * k + "*" * k + " "*i)
      i -= 1
# Out:
#  ******************
#   ****************
#    **************
#     ************
#      **********
#       ********
#        ******
#         ****
#          **
#          **
#         ****
#        ******
#       ********
#      **********
#     ************
#    **************
#   ****************
#  ******************

# %%
for i in range(1,10):
  k = 10 - i
  j = i - 1
  print(" "*k + "*" * i + "*" * j)
  i -= 1
  if i == 8:
    for k in range(i):
      k = 10 - i
      j = i - 1
      print(" "*k + "*" * i + "*" * j)
      i -= 1
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
#   ***************
#    *************
#     ***********
#      *********
#       *******
#        *****
#         ***
#          *

# %%
for i in range(1,10):
  k = 10 - i
  j = i - 1
  print("*"*k + " " * j + " " * j + "*"*k)
  i -= 1
  if i == 8:
    for k in range(i):
      k = 10 - i
      j = i - 1
      print("*"*k + " " * j + " " * j + "*"*k)
      i -= 1
# Out:
# ******************
# ********  ********
# *******    *******
# ******      ******
# *****        *****
# ****          ****
# ***            ***
# **              **
# *                *
# **              **
# ***            ***
# ****          ****
# *****        *****
# ******      ******
# *******    *******
# ********  ********
# ******************

# %%
print(" "*10 + "$")
for i in range(1,10):
  k = 10 - i; j = i - 3; a = i - 2; b = i - 1 ; d = i - 4; e = i - 3
  c = i; f = i - 3; g = i - 4; h = i - 4; l = h - 1; m = i -5; n = m-1
  o = i - 6; p = i - 6; q = p - 1; r = i - 7; s = r - 1; t = i - 8
  if a > 1:
    a = 1
  if e > 1:
    e = 1
  if b > 1:
    b = 1
  if c < 3:
    c = 0
  else:
    c = 1
  if f > 1:
    f = 1
  if g > 1:
    g = 1
  if m > 1:
    m = 1
  if n > 1:
    n = 1
  if o > 1:
    o = 1
  if p > 1:
    p = 1
  if h > 1:
    h = 1
  if l > 1:
    l = 1
  if q > 1:
    q = 1
  if r > 1:
    r = 1
  print(" "*k + "$" +" "+"$"*b + " "*a + "$"*f +" "*h +"$"*m +" "*p + "$"*r + " "*t +"$"*s +" "*q +"$"*o + " "*l + "$"*g  + " "*e + "$"*c +" "*b + "$")
  i -= 1
  if i == 8:
    for k in range(i):
      k = 10 - i; j = i - 3; a = i - 2; b = i - 1 ; d = i - 4; e = i - 3
      c = i; f = i - 3; g = i - 4; h = i - 4; l = h - 1; m = i -5; n = m-1
      o = i - 6; p = i - 6; q = p - 1; r = i - 7; s = r - 1; t = i - 8
      if a > 1:
        a = 1
      if e > 1:
        e = 1
      if b > 1:
        b = 1
      if c < 3:
        c = 0
      else:
        c = 1
      if f > 1:
        f = 1
      if g > 1:
        g = 1
      if m > 1:
        m = 1
      if n > 1:
        n = 1
      if o > 1:
        o = 1
      if p > 1:
        p = 1
      if h > 1:
        h = 1
      if l > 1:
        l = 1
      if q > 1:
        q = 1
      if r > 1:
        r = 1
      print(" "*k + "$" +" "+"$"*b + " "*a + "$"*f +" "*h +"$"*m +" "*p + "$"*r + " "*t +"$"*s +" "*q +"$"*o + " "*l + "$"*g  + " "*e + "$"*c +" "*b + "$")
      i -= 1
print(" "*10 + "$")
# Out:
#           $
#          $ $
#         $ $ $
#        $ $ $ $
#       $ $ $ $ $
#      $ $ $ $ $ $
#     $ $ $ $ $ $ $
#    $ $ $ $ $ $ $ $
#   $ $ $ $ $ $ $ $ $
#  $ $ $ $ $ $ $ $ $ $
#   $ $ $ $ $ $ $ $ $
#    $ $ $ $ $ $ $ $
#     $ $ $ $ $ $ $
#      $ $ $ $ $ $
#       $ $ $ $ $
#        $ $ $ $
#         $ $ $
#          $ $
#           $

# %%
for i in range(10):
  k = 10 - i
  print(" "*k + " $"*i)
  if i == 9:
    for j in range(i):
      a = i - 1
      p = 10 - i
      print(" "+" "*p + " $"*a)
      i -= 1
# Out:
#
#           $
#          $ $
#         $ $ $
#        $ $ $ $
#       $ $ $ $ $
#      $ $ $ $ $ $
#     $ $ $ $ $ $ $
#    $ $ $ $ $ $ $ $
#   $ $ $ $ $ $ $ $ $
#    $ $ $ $ $ $ $ $
#     $ $ $ $ $ $ $
#      $ $ $ $ $ $
#       $ $ $ $ $
#        $ $ $ $
#         $ $ $
#          $ $
#           $

# %%
for i in range(10):
  k = 10 - i
  b = i
  if b >= 1:
    b = 1
  c = 1 - i
  print("*"*k + " $"*i + " "*b + "*"*k + "*"*c)
  if i == 9:
    for j in range(i):
      a = i - 1
      k = 10 - i
      c = i - 1
      if c > 1:
        c = 1
      z = k
      if z == 9:
        z = 10
      print("*"+"*"*k + " $"*a + " "*c + "*"*z + "*" + " ")
      i -= 1
# Out:
# *********************
# ********* $ *********
# ******** $ $ ********
# ******* $ $ $ *******
# ****** $ $ $ $ ******
# ***** $ $ $ $ $ *****
# **** $ $ $ $ $ $ ****
# *** $ $ $ $ $ $ $ ***
# ** $ $ $ $ $ $ $ $ **
# * $ $ $ $ $ $ $ $ $ *
# ** $ $ $ $ $ $ $ $ **
# *** $ $ $ $ $ $ $ ***
# **** $ $ $ $ $ $ ****
# ***** $ $ $ $ $ *****
# ****** $ $ $ $ ******
# ******* $ $ $ *******
# ******** $ $ ********
# ********* $ *********
# *********************
